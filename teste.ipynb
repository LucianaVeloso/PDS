# %% [markdown]
# <a href="https://colab.research.google.com/github/LucianaVeloso/PDS/blob/main/teste.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Isso aqui é meu colab

# %%
print("nao sei oq, nao sei oq la")
# Out:
# nao sei oq, nao sei oq la
